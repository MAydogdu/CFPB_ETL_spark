# %% [markdown]
# ### Consumer Finances Protection Bureau (CFPB)
# #### Consumer Complaint Database
#
# This program gets the complaint database (full dataset) from the web
# and performs some data cleaning and transformation as well as basic univariate data exploration in pyspark.  It then creates a dataframe and exports it into a CSV file that can be used for further analysis.
#
# This is more of an exercise with spark. The full complaints dataset is reasonably small (just over 500MB as of the end of April 2018) so it can be processed in a more traditional way. But this exercise shows the potential of parallel processing as well as challenges that come with it.
#
#
# This version: April 2018

# %%
import pandas as pd
import numpy as np
import time
from datetime import datetime
beg_time = time.clock()

# %%
import sys
#stdout = sys.stdout
#reload(sys)
#sys.setdefaultencoding('utf-8')
#sys.stdout = stdout

# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark.ml.feature import StopWordsRemover

# %%
#spark.stop()

# %%
#https://rea.tech/how-we-optimize-apache-spark-apps/
confM = pyspark.SparkConf().setAll([('spark.executor.memory', '10g'), \
                                    ('spark.executor.cores', '5'), \
                                    ('spark.executor.instances', '25'), \
                                    ('spark.default.parallelism', '100'), \
                                    ('spark.yarn.executor.memoryOverhead', '1g'), \
                                    ('spark.submit.deployMode', 'cluster')])
                                    #('spark.cores.max', '3'), \
                                    #('spark.driver.memory','4g')])

# %%
spark = SparkSession.builder \
    .appName("CFPBETL") \
    .config(conf = confM) \
    .getOrCreate()

# %%
spark.sparkContext.getConf().getAll()
# Out:
# [(u'spark.eventLog.enabled', u'true'),
#  (u'spark.submit.deployMode', u'cluster'),
#  (u'spark.driver.extraLibraryPath',
#   u'/usr/lib/hadoop/lib/native:/usr/lib/hadoop-lzo/lib/native'),
#  (u'spark.executor.cores', u'5'),
#  (u'spark.driver.appUIAddress',
#   u'http://ip-10-0-0-248.us-east-2.compute.internal:4040'),
#  (u'spark.blacklist.decommissioning.timeout', u'1h'),
#  (u'spark.yarn.appMasterEnv.SPARK_PUBLIC_DNS', u'$(hostname -f)'),
#  (u'spark.executor.instances', u'25'),
#  (u'spark.executor.extraJavaOptions',
#   u"-verbose:gc -XX:+PrintGCDetails -XX:+PrintGCDateStamps -XX:+UseConcMarkSweepGC -XX:CMSInitiatingOccupancyFraction=70 -XX:MaxHeapFreeRatio=70 -XX:+CMSClassUnloadingEnabled -XX:OnOutOfMemoryError='kill -9 %p'"),
#  (u'spark.yarn.executor.memoryOverhead', u'1g'),
#  (u'spark.eventLog.dir', u'hdfs:///var/log/spark/apps'),
#  (u'spark.sql.hive.metastore.sharedPrefixes',
#   u'com.amazonaws.services.dynamodbv2'),
#  (u'spark.sql.warehouse.dir', u'hdfs:///user/spark/warehouse'),
#  (u'spark.serializer.objectStreamReset', u'100'),
#  (u'spark.org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter.param.PROXY_HOSTS',
#   u'ip-10-0-0-248.us-east-2.compute.internal'),
#  (u'spark.history.fs.logDirectory', u'hdfs:///var/log/spark/apps'),
#  (u'spark.ui.filters',
#   u'org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter'),
#  (u'spark.yarn.historyServer.address',
#   u'ip-10-0-0-248.us-east-2.compute.internal:18080'),
#  (u'spark.default.parallelism', u'100'),
#  (u'spark.history.ui.port', u'18080'),
#  (u'spark.shuffle.service.enabled', u'true'),
#  (u'spark.executor.memory', u'10g'),
#  (u'spark.hadoop.yarn.timeline-service.enabled', u'false'),
#  (u'spark.resourceManager.cleanupExpiredHost', u'true'),
#  (u'spark.driver.extraClassPath',
#   u'/usr/lib/hadoop-lzo/lib/*:/usr/lib/hadoop/hadoop-aws.jar:/usr/share/aws/aws-java-sdk/*:/usr/share/aws/emr/emrfs/conf:/usr/share/aws/emr/emrfs/lib/*:/usr/share/aws/emr/emrfs/auxlib/*:/usr/share/aws/emr/security/conf:/usr/share/aws/emr/security/lib/*:/usr/share/aws/hmclient/lib/aws-glue-datacatalog-spark-client.jar:/usr/share/java/Hive-JSON-Serde/hive-openx-serde.jar:/usr/share/aws/sagemaker-spark-sdk/lib/sagemaker-spark-sdk.jar'),
#  (u'spark.executor.id', u'driver'),
#  (u'spark.org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter.param.PROXY_URI_BASES',
#   u'http://ip-10-0-0-248.us-east-2.compute.internal:20888/proxy/application_1524659964883_0002'),
#  (u'spark.executorEnv.PYTHONPATH',
#   u'/usr/lib/spark/python/lib/py4j-0.10.6-src.zip:/usr/lib/spark/python/:/usr/lib/spark/python/:<CPS>{{PWD}}/pyspark.zip<CPS>{{PWD}}/py4j-0.10.6-src.zip'),
#  (u'spark.app.name', u'PySparkShell'),
#  (u'spark.files.fetchFailure.unRegisterOutputOnHost', u'true'),
#  (u'spark.driver.extraJavaOptions',
#   u"-XX:+UseConcMarkSweepGC -XX:CMSInitiatingOccupancyFraction=70 -XX:MaxHeapFreeRatio=70 -XX:+CMSClassUnloadingEnabled -XX:OnOutOfMemoryError='kill -9 %p'"),
#  (u'spark.driver.port', u'45201'),
#  (u'spark.ui.proxyBase', u'/proxy/application_1524659964883_0002'),
#  (u'spark.master', u'yarn'),
#  (u'spark.decommissioning.timeout.threshold', u'20'),
#  (u'spark.sql.catalogImplementation', u'hive'),
#  (u'spark.stage.attempt.ignoreOnDecommissionFetchFailure', u'true'),
#  (u'spark.rdd.compress', u'True'),
#  (u'spark.app.id', u'application_1524659964883_0002'),
#  (u'spark.executor.extraClassPath',
#   u'/usr/lib/hadoop-lzo/lib/*:/usr/lib/hadoop/hadoop-aws.jar:/usr/share/aws/aws-java-sdk/*:/usr/share/aws/emr/emrfs/conf:/usr/share/aws/emr/emrfs/lib/*:/usr/share/aws/emr/emrfs/auxlib/*:/usr/share/aws/emr/security/conf:/usr/share/aws/emr/security/lib/*:/usr/share/aws/hmclient/lib/aws-glue-datacatalog-spark-client.jar:/usr/share/java/Hive-JSON-Serde/hive-openx-serde.jar:/usr/share/aws/sagemaker-spark-sdk/lib/sagemaker-spark-sdk.jar'),
#  (u'spark.executor.extraLibraryPath',
#   u'/usr/lib/hadoop/lib/native:/usr/lib/hadoop-lzo/lib/native'),
#  (u'spark.yarn.isPython', u'true'),
#  (u'spark.driver.host', u'ip-10-0-0-248.us-east-2.compute.internal'),
#  (u'spark.dynamicAllocation.enabled', u'true'),
#  (u'spark.ui.showConsoleProgress', u'true'),
#  (u'spark.blacklist.decommissioning.enabled', u'true')]

# %%
# Create a pandas dataframe, then convert it into a spark dataframe
#url = "https://data.consumerfinance.gov/api/views/s6ew-h6mp/rows.csv?accessType=DOWNLOAD"
#Comp = pd.read_csv(url)#.sample(frac=0.01)
# Save original dataset into a CSV file so that we don't have to read from the web 
# each time we run the program
#Comp.to_csv("complaints.csv", index = False)
Comp = pd.read_csv("complaints.csv")#.sample(frac=0.20)
Comp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1019719 entries, 0 to 1019718
# Data columns (total 18 columns):
# Date received                   1019719 non-null object
# Product                         1019719 non-null object
# Sub-product                     784549 non-null object
# Issue                           1019719 non-null object
# Sub-issue                       524369 non-null object
# Consumer complaint narrative    275265 non-null object
# Company public response         315727 non-null object
# Company                         1019719 non-null object
# State                           1007508 non-null object
# ZIP code                        1003161 non-null object
# Tags                            140966 non-null object
# Consumer consent provided?      487479 non-null object
# Submitted via                   1019719 non-null object
# Date sent to company            1019719 non-null object
# Company response to consumer    1019716 non-null object
# Timely response?                1019719 non-null object
# Consumer disputed?              768562 non-null object
# Complaint ID                    1019719 non-null int64
# dtypes: int64(1), object(17)
# memory usage: 140.0+ MB

# %%
# First, remove spaces and non-alphanumeric characters from column names
# so that it will be easy to use them in SparkSQL
Comp.columns=Comp.columns.str.replace('?','')
Comp.columns=Comp.columns.str.replace('-','')
Comp.columns=Comp.columns.str.replace(' ','')

display(Comp)
# Out:
#         Datereceived                  Product  \
# 0         03/12/2014                 Mortgage
# 1         10/01/2016         Credit reporting
# 2         10/17/2016            Consumer Loan
# 3         06/08/2014              Credit card
# 4         09/13/2014          Debt collection
# 5         11/13/2013                 Mortgage
# 6         06/16/2015          Debt collection
# 7         06/15/2015         Credit reporting
# 8         11/13/2015                 Mortgage
# 9         10/21/2014                 Mortgage
# 10        04/14/2017                 Mortgage
# 11        03/30/2012             Student loan
# 12        02/03/2016          Debt collection
# 13        01/07/2015         Credit reporting
# 14        03/15/2013              Credit card
# 15        07/18/2016         Credit reporting
# 16        02/17/2016          Debt collection
# 17        11/07/2014                 Mortgage
# 18        04/17/2015                 Mortgage
# 19        03/09/2016         Credit reporting
# 20        02/04/2015          Debt collection
# 21        03/17/2017  Bank account or service
# 22        03/08/2012                 Mortgage
# 23        03/27/2013                 Mortgage
# 24        02/25/2014          Debt collection
# 25        11/18/2016                 Mortgage
# 26        07/16/2015                 Mortgage
# 27        11/03/2015          Debt collection
# 28        08/09/2016         Credit reporting
# 29        04/27/2016                 Mortgage
# ...              ...                      ...
# 1019689   11/13/2013              Credit card
# 1019690   03/05/2016             Student loan
# 1019691   07/28/2014                 Mortgage
# 1019692   10/21/2015              Credit card
# 1019693   05/05/2016             Student loan
# 1019694   03/25/2014  Bank account or service
# 1019695   08/17/2016                 Mortgage
# 1019696   04/11/2014  Bank account or service
# 1019697   01/26/2017          Debt collection
# 1019698   11/15/2012                 Mortgage
# 1019699   03/19/2017  Bank account or service
# 1019700   12/01/2016          Debt collection
# 1019701   02/27/2017          Debt collection
# 1019702   09/07/2016  Bank account or service
# 1019703   03/16/2017  Bank account or service
# 1019704   03/23/2017  Bank account or service
# 1019705   11/22/2016                 Mortgage
# 1019706   01/18/2017          Debt collection
# 1019707   04/28/2015                 Mortgage
# 1019708   09/12/2012  Bank account or service
# 1019709   09/17/2015              Credit card
# 1019710   02/11/2014              Credit card
# 1019711   11/09/2016          Debt collection
# 1019712   01/22/2016  Bank account or service
# 1019713   01/26/2017          Debt collection
# 1019714   04/10/2017          Debt collection
# 1019715   02/07/2017          Debt collection
# 1019716   01/04/2017                 Mortgage
# 1019717   09/28/2015          Debt collection
# 1019718   08/19/2016          Debt collection
#
#                                      Subproduct  \
# 0                                Other mortgage
# 1                                           NaN
# 2                                  Vehicle loan
# 3                                           NaN
# 4                                   Credit card
# 5        Conventional adjustable mortgage (ARM)
# 6                                       Medical
# 7                                           NaN
# 8                                Other mortgage
# 9                   Conventional fixed mortgage
# 10                               Other mortgage
# 11                     Non-federal student loan
# 12        Other (i.e. phone, health club, etc.)
# 13                                          NaN
# 14                                          NaN
# 15                                          NaN
# 16                                  Credit card
# 17                  Conventional fixed mortgage
# 18                                 FHA mortgage
# 19                                          NaN
# 20                                     Mortgage
# 21                             Checking account
# 22                               Other mortgage
# 23                  Conventional fixed mortgage
# 24        Other (i.e. phone, health club, etc.)
# 25                  Conventional fixed mortgage
# 26                  Conventional fixed mortgage
# 27                                      Medical
# 28                                          NaN
# 29                  Conventional fixed mortgage
# ...                                         ...
# 1019689                                     NaN
# 1019690                Non-federal student loan
# 1019691             Conventional fixed mortgage
# 1019692                                     NaN
# 1019693          Federal student loan servicing
# 1019694                        Checking account
# 1019695             Conventional fixed mortgage
# 1019696                        Checking account
# 1019697   Other (i.e. phone, health club, etc.)
# 1019698                          Other mortgage
# 1019699              Other bank product/service
# 1019700                                Mortgage
# 1019701   Other (i.e. phone, health club, etc.)
# 1019702              Other bank product/service
# 1019703              Other bank product/service
# 1019704                        Checking account
# 1019705             Conventional fixed mortgage
# 1019706   Other (i.e. phone, health club, etc.)
# 1019707                          Other mortgage
# 1019708                        Checking account
# 1019709                                     NaN
# 1019710                                     NaN
# 1019711                                 Medical
# 1019712                        Checking account
# 1019713   Other (i.e. phone, health club, etc.)
# 1019714                             Credit card
# 1019715   Other (i.e. phone, health club, etc.)
# 1019716             Conventional fixed mortgage
# 1019717                Non-federal student loan
# 1019718                             Payday loan
#
#                                             Issue  \
# 0        Loan modification,collection,foreclosure
# 1          Incorrect information on credit report
# 2                      Managing the loan or lease
# 3                                      Bankruptcy
# 4                           Communication tactics
# 5        Loan servicing, payments, escrow account
# 6             Improper contact or sharing of info
# 7        Credit reporting company's investigation
# 8        Loan modification,collection,foreclosure
# 9        Loan modification,collection,foreclosure
# 10       Loan modification,collection,foreclosure
# 11                             Repaying your loan
# 12                Disclosure verification of debt
# 13         Incorrect information on credit report
# 14                     Closing/Cancelling account
# 15         Incorrect information on credit report
# 16            Improper contact or sharing of info
# 17       Loan modification,collection,foreclosure
# 18       Application, originator, mortgage broker
# 19         Incorrect information on credit report
# 20          Cont'd attempts collect debt not owed
# 21       Making/receiving payments, sending money
# 22       Loan servicing, payments, escrow account
# 23       Loan servicing, payments, escrow account
# 24          Cont'd attempts collect debt not owed
# 25                   Settlement process and costs
# 26       Application, originator, mortgage broker
# 27                Disclosure verification of debt
# 28       Credit reporting company's investigation
# 29       Loan servicing, payments, escrow account
# ...                                           ...
# 1019689                          Billing disputes
# 1019690        Dealing with my lender or servicer
# 1019691  Application, originator, mortgage broker
# 1019692                         Billing statement
# 1019693        Dealing with my lender or servicer
# 1019694                 Using a debit or ATM card
# 1019695              Settlement process and costs
# 1019696                 Using a debit or ATM card
# 1019697     Cont'd attempts collect debt not owed
# 1019698  Loan servicing, payments, escrow account
# 1019699                 Using a debit or ATM card
# 1019700     Cont'd attempts collect debt not owed
# 1019701           Disclosure verification of debt
# 1019702                  Deposits and withdrawals
# 1019703  Making/receiving payments, sending money
# 1019704                  Deposits and withdrawals
# 1019705  Loan modification,collection,foreclosure
# 1019706                     Communication tactics
# 1019707  Loan servicing, payments, escrow account
# 1019708  Making/receiving payments, sending money
# 1019709                                   Rewards
# 1019710     Identity theft / Fraud / Embezzlement
# 1019711        False statements or representation
# 1019712                  Deposits and withdrawals
# 1019713     Cont'd attempts collect debt not owed
# 1019714     Cont'd attempts collect debt not owed
# 1019715     Cont'd attempts collect debt not owed
# 1019716  Application, originator, mortgage broker
# 1019717           Disclosure verification of debt
# 1019718     Cont'd attempts collect debt not owed
#
#                                        Subissue  \
# 0                                           NaN
# 1                                Account status
# 2                                           NaN
# 3                                           NaN
# 4                    Frequent or repeated calls
# 5                                           NaN
# 6         Contacted employer after asked not to
# 7                Inadequate help over the phone
# 8                                           NaN
# 9                                           NaN
# 10                                          NaN
# 11                                          NaN
# 12         Not given enough info to verify debt
# 13                               Account status
# 14                                          NaN
# 15                               Account status
# 16        Talked to a third party about my debt
# 17                                          NaN
# 18                                          NaN
# 19                      Information is not mine
# 20                                Debt was paid
# 21                                          NaN
# 22                                          NaN
# 23                                          NaN
# 24                             Debt is not mine
# 25                                          NaN
# 26                                          NaN
# 27         Right to dispute notice not received
# 28            Problem with statement of dispute
# 29                                          NaN
# ...                                         ...
# 1019689                                     NaN
# 1019690        Keep getting calls about my loan
# 1019691                                     NaN
# 1019692                                     NaN
# 1019693   Trouble with how payments are handled
# 1019694                                     NaN
# 1019695                                     NaN
# 1019696                                     NaN
# 1019697       Debt resulted from identity theft
# 1019698                                     NaN
# 1019699                                     NaN
# 1019700       Debt was discharged in bankruptcy
# 1019701  Not disclosed as an attempt to collect
# 1019702                                     NaN
# 1019703                                     NaN
# 1019704                                     NaN
# 1019705                                     NaN
# 1019706   Used obscene/profane/abusive language
# 1019707                                     NaN
# 1019708                                     NaN
# 1019709                                     NaN
# 1019710                                     NaN
# 1019711       Attempted to collect wrong amount
# 1019712                                     NaN
# 1019713                        Debt is not mine
# 1019714                        Debt is not mine
# 1019715                        Debt is not mine
# 1019716                                     NaN
# 1019717    Not given enough info to verify debt
# 1019718                        Debt is not mine
#
#                                 Consumercomplaintnarrative  \
# 0                                                      NaN
# 1        I have outdated information on my credit repor...
# 2        I purchased a new car on XXXX XXXX. The car de...
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
# 6                                                      NaN
# 7        An account on my credit report has a mistaken ...
# 8                                                      NaN
# 9                                                      NaN
# 10                                                     NaN
# 11                                                     NaN
# 12       This company refuses to provide me verificatio...
# 13                                                     NaN
# 14                                                     NaN
# 15                                                     NaN
# 16       This complaint is in regards to Square Two Fin...
# 17                                                     NaN
# 18                                                     NaN
# 19                                                     NaN
# 20                                                     NaN
# 21                                                     NaN
# 22                                                     NaN
# 23                                                     NaN
# 24                                                     NaN
# 25       Started the refinance of home mortgage process...
# 26       In XXXX, I and my ex-husband applied for a ref...
# 27                                                     NaN
# 28       I have disputed several accounts on my credit ...
# 29       Mortgage was transferred to Nationstar as of X...
# ...                                                    ...
# 1019689                                                NaN
# 1019690                                                NaN
# 1019691                                                NaN
# 1019692                                                NaN
# 1019693  ECSI XXXX., based in XXXX, PA, services my XXX...
# 1019694                                                NaN
# 1019695  I have a mortgage with Caliber Home Loans ( Ac...
# 1019696                                                NaN
# 1019697                                                NaN
# 1019698                                                NaN
# 1019699  My credit report is being negatively affected ...
# 1019700                                                NaN
# 1019701  I have never had XXXX billing, and do not owe ...
# 1019702                                                NaN
# 1019703                                                NaN
# 1019704                                                NaN
# 1019705                                                NaN
# 1019706                                                NaN
# 1019707                                                NaN
# 1019708                                                NaN
# 1019709  Barclay closed my Barclay XXXX MasterCard acco...
# 1019710                                                NaN
# 1019711  Our son was taken to XXXX XXXX XXXX XXXX XXXX ...
# 1019712  On XXXX/XXXX/13, without my authorization, Ban...
# 1019713                                                NaN
# 1019714                                                NaN
# 1019715  I had an account with XXXX in XX/XX/XXXX this ...
# 1019716  I was contacted on XX/XX/XXXX email by XXXX fr...
# 1019717                                                NaN
# 1019718  I had a debit that was included in my chapter ...
#
#                                      Companypublicresponse  \
# 0                                                      NaN
# 1        Company has responded to the consumer and the ...
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
# 6        Company believes it acted appropriately as aut...
# 7         Company chooses not to provide a public response
# 8        Company believes it acted appropriately as aut...
# 9                                                      NaN
# 10       Company believes it acted appropriately as aut...
# 11                                                     NaN
# 12                                                     NaN
# 13                                                     NaN
# 14                                                     NaN
# 15                                                     NaN
# 16       Company has responded to the consumer and the ...
# 17                                                     NaN
# 18                                                     NaN
# 19       Company has responded to the consumer and the ...
# 20                                                     NaN
# 21       Company believes it acted appropriately as aut...
# 22                                                     NaN
# 23                                                     NaN
# 24                                                     NaN
# 25                                                     NaN
# 26                                                     NaN
# 27        Company chooses not to provide a public response
# 28                                                     NaN
# 29                                                     NaN
# ...                                                    ...
# 1019689                                                NaN
# 1019690                                                NaN
# 1019691                                                NaN
# 1019692   Company chooses not to provide a public response
# 1019693                                                NaN
# 1019694                                                NaN
# 1019695                                                NaN
# 1019696                                                NaN
# 1019697  Company believes it acted appropriately as aut...
# 1019698                                                NaN
# 1019699  Company has responded to the consumer and the ...
# 1019700  Company can't verify or dispute the facts in t...
# 1019701  Company believes it acted appropriately as aut...
# 1019702  Company has responded to the consumer and the ...
# 1019703  Company has responded to the consumer and the ...
# 1019704  Company has responded to the consumer and the ...
# 1019705  Company has responded to the consumer and the ...
# 1019706  Company has responded to the consumer and the ...
# 1019707                                                NaN
# 1019708                                                NaN
# 1019709   Company chooses not to provide a public response
# 1019710                                                NaN
# 1019711  Company believes complaint caused principally ...
# 1019712   Company chooses not to provide a public response
# 1019713                                                NaN
# 1019714  Company has responded to the consumer and the ...
# 1019715  Company believes it acted appropriately as aut...
# 1019716                                                NaN
# 1019717   Company chooses not to provide a public response
# 1019718  Company believes it acted appropriately as aut...
#
#                                         Company State ZIPcode            Tags  \
# 0                          M&T BANK CORPORATION    MI   48382             NaN
# 1        TRANSUNION INTERMEDIATE HOLDINGS, INC.    AL   352XX             NaN
# 2                CITIZENS FINANCIAL GROUP, INC.    PA   177XX  Older American
# 3                      AMERICAN EXPRESS COMPANY    ID   83854  Older American
# 4                                CITIBANK, N.A.    VA   23233             NaN
# 5                                  U.S. BANCORP    MN   48322             NaN
# 6                   California Accounts Service    CA   92111             NaN
# 7           Experian Information Solutions Inc.    VA   224XX             NaN
# 8                            Aldridge Pite, LLP    CA   93101             NaN
# 9                      OCWEN LOAN SERVICING LLC    FL   32714  Older American
# 10                     Shellpoint Partners, LLC    CA   90305             NaN
# 11             Student Loan Finance Corporation    MN   55428             NaN
# 12                          The CBE Group, Inc.    TX   752XX             NaN
# 13          Experian Information Solutions Inc.    NV   89169             NaN
# 14                 FIRST NATIONAL BANK OF OMAHA    NY   11732             NaN
# 15                                EQUIFAX, INC.    FL   33629             NaN
# 16              SQUARETWO FINANCIAL CORPORATION    NE   693XX             NaN
# 17                                 U.S. BANCORP    MT   59801             NaN
# 18                        WELLS FARGO & COMPANY    ME   04032             NaN
# 19          Experian Information Solutions Inc.    CA   92703             NaN
# 20            PHH Mortgage Services Corporation    CA   92021             NaN
# 21       UNITED SERVICES AUTOMOBILE ASSOCIATION    WI   54005             NaN
# 22                         Ditech Financial LLC    CA   95361             NaN
# 23                          NATIONSTAR MORTGAGE    WA   98203             NaN
# 24                      Navient Solutions, LLC.    RI   02906             NaN
# 25               AMERICAN NEIGHBORHOOD MORTGAGE    NJ   088XX             NaN
# 26             HSBC NORTH AMERICA HOLDINGS INC.    IL   625XX             NaN
# 27                 Revenue Recovery Corporation    FL   34105             NaN
# 28                                EQUIFAX, INC.    MS   390XX             NaN
# 29                          NATIONSTAR MORTGAGE    CA   954XX             NaN
# ...                                         ...   ...     ...             ...
# 1019689                          CITIBANK, N.A.    IL   61568   Servicemember
# 1019690                 Navient Solutions, LLC.    PR   00738             NaN
# 1019691            FIRST GUARANTY MORTGAGE CORP    MD   20603             NaN
# 1019692                          CITIBANK, N.A.    CO   81631             NaN
# 1019693           HEARTLAND PAYMENT SYSTEMS INC    CA   934XX             NaN
# 1019694    SANTANDER BANK, NATIONAL ASSOCIATION    MA   01952             NaN
# 1019695                Caliber Home Loans, Inc.    TX   774XX             NaN
# 1019696                          CITIBANK, N.A.    NY   10591             NaN
# 1019697                                     ERC    IL   60073             NaN
# 1019698   BANK OF AMERICA, NATIONAL ASSOCIATION    MA   01028             NaN
# 1019699                        BB&T CORPORATION    TX   752XX             NaN
# 1019700                    Ditech Financial LLC    AZ   85383             NaN
# 1019701                                     ERC    NY   136XX             NaN
# 1019702   BANK OF AMERICA, NATIONAL ASSOCIATION    NY   11372             NaN
# 1019703   BANK OF AMERICA, NATIONAL ASSOCIATION    OH   43207             NaN
# 1019704   BANK OF AMERICA, NATIONAL ASSOCIATION    IL   60634             NaN
# 1019705                FREEDOM MORTGAGE COMPANY    MS   39560   Servicemember
# 1019706                       I.C. System, Inc.    TX   75181             NaN
# 1019707                Lynx Asset Services, LLC    NJ   08555             NaN
# 1019708      BBVA COMPASS FINANCIAL CORPORATION    FL   34786             NaN
# 1019709                  BARCLAYS BANK DELAWARE    IN   461XX             NaN
# 1019710       CAPITAL ONE FINANCIAL CORPORATION    WV   25504  Older American
# 1019711           R & B Corporation of Virginia    NJ   077XX             NaN
# 1019712   BANK OF AMERICA, NATIONAL ASSOCIATION    FL   347XX             NaN
# 1019713                 North Shore Agency, LLC    OR   97355             NaN
# 1019714           PENTAGON FEDERAL CREDIT UNION    TX   77802             NaN
# 1019715                                     ERC    NY   115XX   Servicemember
# 1019716                Caliber Home Loans, Inc.    FL   336XX             NaN
# 1019717    Progressive Financial Services, Inc.    OH   44017             NaN
# 1019718                Midwest Recovery Systems    FL   336XX             NaN
#
#         Consumerconsentprovided Submittedvia Datesenttocompany  \
# 0                           NaN     Referral        03/17/2014
# 1              Consent provided          Web        10/05/2016
# 2              Consent provided          Web        10/20/2016
# 3                           NaN          Web        06/10/2014
# 4                           NaN          Web        09/13/2014
# 5                           NaN        Phone        11/20/2013
# 6          Consent not provided          Web        06/19/2015
# 7              Consent provided          Web        06/15/2015
# 8                           NaN     Referral        12/10/2015
# 9                           NaN          Web        10/21/2014
# 10                          NaN     Referral        04/14/2017
# 11                          NaN          Web        07/12/2012
# 12             Consent provided          Web        02/03/2016
# 13                          NaN     Referral        01/23/2015
# 14                          NaN     Referral        03/18/2013
# 15                          NaN          Fax        07/19/2016
# 16             Consent provided          Web        03/04/2016
# 17                          NaN          Web        11/07/2014
# 18         Consent not provided          Web        04/17/2015
# 19                          NaN        Phone        03/09/2016
# 20                          NaN          Web        02/10/2015
# 21                          NaN     Referral        03/20/2017
# 22                          NaN          Web        03/23/2012
# 23                          NaN          Web        03/27/2013
# 24                          NaN          Web        02/24/2014
# 25             Consent provided          Web        11/21/2016
# 26             Consent provided          Web        07/16/2015
# 27                          NaN  Postal mail        11/04/2015
# 28             Consent provided          Web        08/09/2016
# 29             Consent provided          Web        04/27/2016
# ...                         ...          ...               ...
# 1019689                     NaN          Web        11/12/2013
# 1019690    Consent not provided          Web        03/08/2016
# 1019691                     NaN          Web        07/28/2014
# 1019692                     NaN     Referral        10/23/2015
# 1019693        Consent provided          Web        05/09/2016
# 1019694                     NaN          Web        03/25/2014
# 1019695        Consent provided          Web        08/17/2016
# 1019696                     NaN     Referral        04/16/2014
# 1019697    Consent not provided          Web        01/26/2017
# 1019698                     NaN     Referral        11/19/2012
# 1019699        Consent provided          Web        03/19/2017
# 1019700                     NaN     Referral        12/01/2016
# 1019701        Consent provided          Web        02/27/2017
# 1019702                     NaN     Referral        09/12/2016
# 1019703                     NaN          Fax        03/30/2017
# 1019704    Consent not provided          Web        03/23/2017
# 1019705                     NaN        Phone        11/22/2016
# 1019706    Consent not provided          Web        01/19/2017
# 1019707                     NaN     Referral        05/01/2015
# 1019708                     NaN     Referral        09/13/2012
# 1019709        Consent provided          Web        09/17/2015
# 1019710                     NaN          Web        02/11/2014
# 1019711        Consent provided          Web        11/09/2016
# 1019712        Consent provided          Web        01/22/2016
# 1019713                     NaN     Referral        01/31/2017
# 1019714                     NaN     Referral        04/11/2017
# 1019715        Consent provided          Web        02/07/2017
# 1019716        Consent provided          Web        01/04/2017
# 1019717                     NaN  Postal mail        09/30/2015
# 1019718        Consent provided          Web        08/19/2016
#
#            Companyresponsetoconsumer Timelyresponse Consumerdisputed  \
# 0            Closed with explanation            Yes               No
# 1            Closed with explanation            Yes               No
# 2            Closed with explanation            Yes               No
# 3            Closed with explanation            Yes              Yes
# 4            Closed with explanation            Yes              Yes
# 5        Closed with monetary relief            Yes               No
# 6            Closed with explanation            Yes               No
# 7            Closed with explanation            Yes               No
# 8            Closed with explanation            Yes              Yes
# 9            Closed with explanation            Yes               No
# 10           Closed with explanation            Yes               No
# 11           Closed with explanation            Yes               No
# 12           Closed with explanation            Yes              Yes
# 13           Closed with explanation            Yes              Yes
# 14           Closed with explanation            Yes               No
# 15           Closed with explanation            Yes               No
# 16           Closed with explanation            Yes              Yes
# 17           Closed with explanation            Yes               No
# 18           Closed with explanation            Yes               No
# 19           Closed with explanation            Yes               No
# 20           Closed with explanation            Yes              Yes
# 21           Closed with explanation            Yes               No
# 22             Closed without relief            Yes               No
# 23           Closed with explanation            Yes               No
# 24           Closed with explanation            Yes              Yes
# 25       Closed with monetary relief             No               No
# 26           Closed with explanation            Yes               No
# 27           Closed with explanation            Yes               No
# 28           Closed with explanation            Yes              Yes
# 29           Closed with explanation            Yes              Yes
# ...                              ...            ...              ...
# 1019689  Closed with monetary relief            Yes               No
# 1019690  Closed with monetary relief            Yes               No
# 1019691  Closed with monetary relief            Yes               No
# 1019692  Closed with monetary relief            Yes               No
# 1019693      Closed with explanation            Yes               No
# 1019694  Closed with monetary relief            Yes               No
# 1019695      Closed with explanation            Yes              Yes
# 1019696  Closed with monetary relief            Yes               No
# 1019697                       Closed            Yes               No
# 1019698  Closed with monetary relief            Yes               No
# 1019699      Closed with explanation            Yes               No
# 1019700      Closed with explanation            Yes               No
# 1019701                       Closed            Yes              Yes
# 1019702  Closed with monetary relief            Yes               No
# 1019703      Closed with explanation            Yes               No
# 1019704      Closed with explanation            Yes               No
# 1019705      Closed with explanation            Yes              Yes
# 1019706      Closed with explanation            Yes               No
# 1019707      Closed with explanation            Yes              Yes
# 1019708  Closed with monetary relief            Yes               No
# 1019709  Closed with monetary relief            Yes               No
# 1019710  Closed with monetary relief            Yes               No
# 1019711      Closed with explanation            Yes               No
# 1019712  Closed with monetary relief            Yes               No
# 1019713      Closed with explanation            Yes               No
# 1019714      Closed with explanation            Yes               No
# 1019715                       Closed            Yes               No
# 1019716      Closed with explanation            Yes               No
# 1019717      Closed with explanation            Yes               No
# 1019718      Closed with explanation            Yes              Yes
#
#          ComplaintID
# 0             759217
# 1            2141773
# 2            2163100
# 3             885638
# 4            1027760
# 5             596562
# 6            1422680
# 7            1420702
# 8            1654890
# 9            1079567
# 10           2436165
# 11             42864
# 12           1772196
# 13           1184859
# 14            357186
# 15           2017178
# 16           1790634
# 17           1107428
# 18           1334421
# 19           1823789
# 20           1224106
# 21           2393048
# 22             32412
# 23            366548
# 24            730165
# 25           2216206
# 26           1472017
# 27           1637385
# 28           2051099
# 29           1898476
# ...              ...
# 1019689       595723
# 1019690      1817381
# 1019691       955942
# 1019692      1618142
# 1019693      1912906
# 1019694       776970
# 1019695      2069434
# 1019696       805874
# 1019697      2313827
# 1019698       192117
# 1019699      2393820
# 1019700      2231005
# 1019701      2361759
# 1019702      2099790
# 1019703      2391539
# 1019704      2402119
# 1019705      2219420
# 1019706      2295668
# 1019707      1350374
# 1019708       150106
# 1019709      1568426
# 1019710       710260
# 1019711      2201681
# 1019712      1753439
# 1019713      2313821
# 1019714      2428130
# 1019715      2331270
# 1019716      2274241
# 1019717      1582525
# 1019718      2073214
#
# [1019719 rows x 18 columns]

# %% [markdown]
# $ $
# #### Missing values
# $ $
#
# There are many missing values in the dataset. Convert those into a category by recoding them as xxxxx This makes working with them easier (GroupBy, etc), since treatment of missing values can vary.
#
# This replacement is done on the pandas dataframe, before creating the spark dataframe.
# $ $

# %%
# Creating a spark dataframe:
# Directly reading from the CSV with the CFPB URL didn't work, even while I tried many varions like
# df = (sql.read.format("csv").options(header="true").load(url))

# The code below helps with "merge" error that was given for direct spark DF creation
# This may have to do with missing values
for col in Comp.columns:
    if ((Comp[col].dtypes != np.int64) & (Comp[col].dtypes != np.float64)):
        Comp[col] = Comp[col].fillna('xxxxx')

df = spark.createDataFrame(Comp)

# %%
df.printSchema()
# Out:
# root
#  |-- Datereceived: string (nullable = true)
#  |-- Product: string (nullable = true)
#  |-- Subproduct: string (nullable = true)
#  |-- Issue: string (nullable = true)
#  |-- Subissue: string (nullable = true)
#  |-- Consumercomplaintnarrative: string (nullable = true)
#  |-- Companypublicresponse: string (nullable = true)
#  |-- Company: string (nullable = true)
#  |-- State: string (nullable = true)
#  |-- ZIPcode: string (nullable = true)
#  |-- Tags: string (nullable = true)
#  |-- Consumerconsentprovided: string (nullable = true)
#  |-- Submittedvia: string (nullable = true)
#  |-- Datesenttocompany: string (nullable = true)
#  |-- Companyresponsetoconsumer: string (nullable = true)
#  |-- Timelyresponse: string (nullable = true)
#  |-- Consumerdisputed: string (nullable = true)
#  |-- ComplaintID: long (nullable = true)

# %%
df.count()
# Out:
# 1019719

# %%
df.show(n=10)
# Out:
# +------------+----------------+--------------------+--------------------+--------------------+--------------------------+---------------------+--------------------+-----+-------+--------------+-----------------------+------------+-----------------+-------------------------+--------------+----------------+-----------+
# |Datereceived|         Product|          Subproduct|               Issue|            Subissue|Consumercomplaintnarrative|Companypublicresponse|             Company|State|ZIPcode|          Tags|Consumerconsentprovided|Submittedvia|Datesenttocompany|Companyresponsetoconsumer|Timelyresponse|Consumerdisputed|ComplaintID|
# +------------+----------------+--------------------+--------------------+--------------------+--------------------------+---------------------+--------------------+-----+-------+--------------+-----------------------+------------+-----------------+-------------------------+--------------+----------------+-----------+
# |  03/12/2014|        Mortgage|      Other mortgage|Loan modification...|               xxxxx|                     xxxxx|                xxxxx|M&T BANK CORPORATION|   MI|  48382|         xxxxx|                  xxxxx|    Referral|       03/17/2014|     Closed with expla...|           Yes|              No|     759217|
# |  10/01/2016|Credit reporting|               xxxxx|Incorrect informa...|      Account status|      I have outdated i...| Company has respo...|TRANSUNION INTERM...|   AL|  352XX|         xxxxx|       Consent provided|         Web|       10/05/2016|     Closed with expla...|           Yes|              No|    2141773|
# |  10/17/2016|   Consumer Loan|        Vehicle loan|Managing the loan...|               xxxxx|      I purchased a new...|                xxxxx|CITIZENS FINANCIA...|   PA|  177XX|Older American|       Consent provided|         Web|       10/20/2016|     Closed with expla...|           Yes|              No|    2163100|
# |  06/08/2014|     Credit card|               xxxxx|          Bankruptcy|               xxxxx|                     xxxxx|                xxxxx|AMERICAN EXPRESS ...|   ID|  83854|Older American|                  xxxxx|         Web|       06/10/2014|     Closed with expla...|           Yes|             Yes|     885638|
# |  09/13/2014| Debt collection|         Credit card|Communication tac...|Frequent or repea...|                     xxxxx|                xxxxx|      CITIBANK, N.A.|   VA|  23233|         xxxxx|                  xxxxx|         Web|       09/13/2014|     Closed with expla...|           Yes|             Yes|    1027760|
# |  11/13/2013|        Mortgage|Conventional adju...|Loan servicing, p...|               xxxxx|                     xxxxx|                xxxxx|        U.S. BANCORP|   MN|  48322|         xxxxx|                  xxxxx|       Phone|       11/20/2013|     Closed with monet...|           Yes|              No|     596562|
# |  06/16/2015| Debt collection|             Medical|Improper contact ...|Contacted employe...|                     xxxxx| Company believes ...|California Accoun...|   CA|  92111|         xxxxx|   Consent not provided|         Web|       06/19/2015|     Closed with expla...|           Yes|              No|    1422680|
# |  06/15/2015|Credit reporting|               xxxxx|Credit reporting ...|Inadequate help o...|      An account on my ...| Company chooses n...|Experian Informat...|   VA|  224XX|         xxxxx|       Consent provided|         Web|       06/15/2015|     Closed with expla...|           Yes|              No|    1420702|
# |  11/13/2015|        Mortgage|      Other mortgage|Loan modification...|               xxxxx|                     xxxxx| Company believes ...|  Aldridge Pite, LLP|   CA|  93101|         xxxxx|                  xxxxx|    Referral|       12/10/2015|     Closed with expla...|           Yes|             Yes|    1654890|
# |  10/21/2014|        Mortgage|Conventional fixe...|Loan modification...|               xxxxx|                     xxxxx|                xxxxx|OCWEN LOAN SERVIC...|   FL|  32714|Older American|                  xxxxx|         Web|       10/21/2014|     Closed with expla...|           Yes|              No|    1079567|
# +------------+----------------+--------------------+--------------------+--------------------+--------------------------+---------------------+--------------------+-----+-------+--------------+-----------------------+------------+-----------------+-------------------------+--------------+----------------+-----------+
# only showing top 10 rows

# %%
# Make sure there are no ComplaintID duplicates. Then remove this feature.
df = df.dropDuplicates(['ComplaintID'])
df = df.drop('ComplaintID')
#df.count()

# %% [markdown]
# $ $
# #### Product and Sub-product
# $ $

# %%
# SQL: Counts of Product + Subproduct sorted in a descending order of count
# groupBy also works similarly for these 
df.createOrReplaceTempView("Prod")

ProdDF = spark.sql("SELECT Product, Subproduct, count(*) as cnt \
                    FROM Prod \
                    GROUP BY Product, Subproduct \
                    ORDER BY cnt DESC")
#ProdDF.show()
#ProdDF.count()
ProdDF.coalesce(1).write.csv(path="Products.csv", mode="append", header = "true", sep='\t')

# %% [markdown]
# $ $
#
# Spark: The product - sub-product table above is written into a tab-delimited file first. A new, combined product classification is created . Any subcategory that has more than 10,000 observations is kept as a separate product. Smaller sub-categories are folded into a generic "other" category.
#
# Note: Spark creates a directory named Products.csv instead of a file under HDFS (/user/hadoop/Products.csv). Hadoop datanode tool (50070) has a "Browse the file system" tool that can be used to view/download the output. There will be a single CSV file in that directory that will need to be recoded. I have manually recoded Product + Subproduct combinations into a single, combined categorical variable using a spreadsheet. The code below tham imports the recoded file back into this environment.
#
# $ $

# %%
# This code reads the updated product CSV file into a spark dataframe
Prod = spark.read.format("csv").option("header", "true").load("Products_recoded.csv")
#Prod.show()

# %%
# Merge the new (product+sub-product) variable with the main data frame
# SQL version 
df.createOrReplaceTempView("P1")
Prod.createOrReplaceTempView("P2")

df = spark.sql("SELECT a.*, b.Prod \
                    FROM P1 a  LEFT JOIN P2 b\
                    ON a.Product == b.Product AND a.Subproduct == b.Subproduct")
#df.show()

# %% [markdown]
# $ $
# #### Recode Product and Sub-product
# $ $
#
#
#
#
# By combining Product and Sub-product, we get a new categorical feature with about 20 categories. All but four of these categories have more than 10,000 observations.
#
# $ $

# %%
# Here is the new variable with counts
df.groupBy('Prod').count().orderBy('count', ascending=False).show()
# Out:
# +--------------------+------+
# |                Prod| count|
# +--------------------+------+
# |    Credit reporting|248970|
# |Debt collection -...|145241|
# |    Mortgage - other|117762|
# |Credit card or pr...|115419|
# |Mortgage - conven...| 70616|
# |Bank account or s...| 59045|
# |Bank account or s...| 45744|
# |Debt collection -...| 28700|
# |Mortgage - FHA mo...| 28192|
# |Mortgage - conven...| 25381|
# |Student loan - no...| 22283|
# |Debt collection -...| 21205|
# |Consumer loan - v...| 17782|
# |Student loan - fe...| 16556|
# |Consumer loan - o...| 13825|
# |Mortgage - home e...| 11625|
# |     Money transfers| 11047|
# |Payday loan, titl...|  9825|
# |Other financial s...|  6476|
# |Student loan - other|  3937|
# +--------------------+------+
# only showing top 20 rows

# %%
# Since we no longer need the two original features, we can delete them. 
df = df.drop('Product','Subproduct')
df.printSchema()
# Out:
# root
#  |-- Datereceived: string (nullable = true)
#  |-- Issue: string (nullable = true)
#  |-- Subissue: string (nullable = true)
#  |-- Consumercomplaintnarrative: string (nullable = true)
#  |-- Companypublicresponse: string (nullable = true)
#  |-- Company: string (nullable = true)
#  |-- State: string (nullable = true)
#  |-- ZIPcode: string (nullable = true)
#  |-- Tags: string (nullable = true)
#  |-- Consumerconsentprovided: string (nullable = true)
#  |-- Submittedvia: string (nullable = true)
#  |-- Datesenttocompany: string (nullable = true)
#  |-- Companyresponsetoconsumer: string (nullable = true)
#  |-- Timelyresponse: string (nullable = true)
#  |-- Consumerdisputed: string (nullable = true)
#  |-- Prod: string (nullable = true)

# %% [markdown]
# $ $
#
# #### Issue and Sub-issue
#
# $ $
#
# These two features are combined into one in a manner similar to Product and Sub-product. There are many more categories here, though.
# $ $

# %%
df.createOrReplaceTempView("Iss")

IssDF = spark.sql("SELECT Issue, Subissue, count(*) as cnt \
                    FROM Iss \
                    GROUP BY Issue, Subissue \
                    ORDER BY cnt DESC")

# %%
IssDF.count()
IssDF.coalesce(1).write.csv(path="Issues.csv", mode="append", header = "true", sep='\t')

# %% [markdown]
# $ $
#
# Spark: The product - sub-product table above is written into a tab-delimited file first. A new, combined product classification is created . Any subcategory that has more than 10,000 observations is kept as a separate product. Smaller sub-categories are folded into a generic "other" category.
#
# $ $

# %%
# This code reads the updated Issues CSV file into a spark dataframe
Iss = spark.read.format("csv").option("header", "true").load("Issues_recoded.csv")

# %%
# Merge the new (product+sub-product) variable with the main data frame
df.createOrReplaceTempView("P1")
Iss.createOrReplaceTempView("P2")

df = spark.sql("SELECT a.*, b.Iss \
                    FROM P1 a  LEFT JOIN P2 b\
                    ON a.Issue == b.Issue AND a.Subissue == b.Subissue")

# %%
df.groupBy('Iss').count().orderBy('count', ascending=False).show()
# Out:
# +--------------------+------+
# |                 Iss| count|
# +--------------------+------+
# |               Other|136567|
# |Loan modification...|112314|
# |Loan servicing, p...| 77337|
# |Incorrect informa...| 59564|
# |Account opening, ...| 37961|
# |Incorrect informa...| 37057|
# |Cont'd attempts c...| 36743|
# |Incorrect informa...| 32385|
# |Deposits and with...| 22851|
# |Problem with a cr...| 22069|
# |Disclosure verifi...| 21820|
# |Improper use of m...| 21060|
# |Attempts to colle...| 20338|
# |Dealing with my l...| 18503|
# |Communication tac...| 17623|
# |Managing the loan...| 17324|
# |Application, orig...| 17233|
# |Cont'd attempts c...| 16632|
# |Struggling to pay...| 15163|
# |    Billing disputes| 15136|
# +--------------------+------+
# only showing top 20 rows

# %%
# Remove the original two variables since they are now recoded
df = df.drop('Issue','Subissue')
df.printSchema()
# Out:
# root
#  |-- Datereceived: string (nullable = true)
#  |-- Consumercomplaintnarrative: string (nullable = true)
#  |-- Companypublicresponse: string (nullable = true)
#  |-- Company: string (nullable = true)
#  |-- State: string (nullable = true)
#  |-- ZIPcode: string (nullable = true)
#  |-- Tags: string (nullable = true)
#  |-- Consumerconsentprovided: string (nullable = true)
#  |-- Submittedvia: string (nullable = true)
#  |-- Datesenttocompany: string (nullable = true)
#  |-- Companyresponsetoconsumer: string (nullable = true)
#  |-- Timelyresponse: string (nullable = true)
#  |-- Consumerdisputed: string (nullable = true)
#  |-- Prod: string (nullable = true)
#  |-- Iss: string (nullable = true)

# %% [markdown]
# ### Consumer complaint narrative
# $ $
# This section largely draws from my previous work. It first cleans the narrative by stripping stop words, punctuation marks etc. Then, it counts the positive and negative words using the Loughran - McDonald finance sentiment dictionary. The following are recorded:
#
# * 'Clean' narrative: an array of non-stop words and its length (word count)
# * Positive and negative word arrays and their lengths
# * Percent sentiment: Difference in Positive and Negative word array lengths divided by the sum of those two numbers. By construction, this number will be between 100% and -100%.
#
# $ $

# %%
positives = open('LoughranMcDonald_Positive.csv', "r").readlines()
positive = [pos.strip().lower().split(',')[0] for pos in positives]
negatives = open('LoughranMcDonald_Negative.csv', "r").readlines()
negative = [neg.strip().lower().split(',')[0] for neg in negatives]

# %%
# Transform the narrative: (1) lowercase, (2) remove punctuation, (3) split into words, 
# and (4) remove stopwords 
# Also, record the length of the narrative after removing stopwords

df = df.withColumn('Nr', lower(regexp_replace(df.Consumercomplaintnarrative,'[^\w\s]',' ')))
df = df.withColumn('Spl', split('Nr', "\s+"))

remover = StopWordsRemover(inputCol='Spl', outputCol='Narr')
remover.loadDefaultStopWords('english')
df = remover.transform(df)
df = df.withColumn('NarrLength', size('Narr'))

# %%
# Right now, the same function works on the same narrative twice
# one to find the positive words, and another to find the negative words
# There may be an easier way to do this
def inListPos(narrative):
    x = [ ]
    for word in narrative:
        if word in (positive):
            x.append(word)        
    return x
def inListNeg(narrative):
    x = [ ]
    for word in narrative:
        if word in (negative):
            x.append(word)
    return x
pUDF = udf(inListPos,ArrayType(StringType()))
nUDF = udf(inListNeg,ArrayType(StringType()))
df = df.withColumn('Pos',pUDF(df['Narr']))
df = df.withColumn('Neg',nUDF(df['Narr']))
df = df.withColumn('PosLength',size('Pos'))
df = df.withColumn('NegLength',size('Neg'))
df = df.withColumn('PSent',(df.PosLength -  df.NegLength) / (df.PosLength + df.NegLength))

# %%
# Here is how the narrative looks after all the transformations
df.filter(df.Consumercomplaintnarrative != 'xxxxx')\
  .select('Consumercomplaintnarrative','Nr','Spl',\
          'Narr', 'NarrLength','Pos','PosLength','Neg','NegLength', 'PSent').show(n=50)
# Out:
# +--------------------------+--------------------+--------------------+--------------------+----------+--------------------+---------+--------------------+---------+-------------------+
# |Consumercomplaintnarrative|                  Nr|                 Spl|                Narr|NarrLength|                 Pos|PosLength|                 Neg|NegLength|              PSent|
# +--------------------------+--------------------+--------------------+--------------------+----------+--------------------+---------+--------------------+---------+-------------------+
# |      I am the Trustee ...|i am the trustee ...|[i, am, the, trus...|[trustee, sister,...|        98|          [superior]|        1|[questions, quest...|        5|-0.6666666666666666|
# |      This dispute cent...|this dispute cent...|[this, dispute, c...|[dispute, centers...|       349|[outstanding, sat...|        8|[dispute, unlawfu...|       19|-0.4074074074074074|
# |      Bank of America r...|bank of america r...|[bank, of, americ...|[bank, america, r...|        69|                  []|        0|            [denied]|        1|               -1.0|
# |      In XX/XX/XXXX I v...|in xx xx xxxx i v...|[in, xx, xx, xxxx...|[xx, xx, xxxx, vi...|       171|[better, transpar...|        3|[subjected, unabl...|       16|-0.6842105263157895|
# |      Thru a company  c...|thru a company  c...|[thru, a, company...|[thru, company, c...|       171|     [able, despite]|        2|[unpaid, summons,...|        6|               -0.5|
# |      Having participat...|having participat...|[having, particip...|[participated, cr...|       182|                  []|        0|[delay, ignored, ...|       12|               -1.0|
# |      debt was discharg...|debt was discharg...|[debt, was, disch...|[debt, discharged...|         7|                  []|        0|        [foreclosed]|        1|               -1.0|
# |      I bank with PNC B...|i bank with pnc b...|[i, bank, with, p...|[bank, pnc, bank,...|       128|       [outstanding]|        1|[declined, negati...|        5|-0.6666666666666666|
# |      I received a call...|i received a call...|[i, received, a, ...|[received, call, ...|        37|              [good]|        1|          [claiming]|        1|                0.0|
# |      In XXXX XX/XX/201...|in xxxx xx xx 201...|[in, xxxx, xx, xx...|[xxxx, xx, xx, 20...|       110|              [able]|        1|[closing, complic...|        2|-0.3333333333333333|
# |      My credit score i...|my credit score i...|[my, credit, scor...|[credit, score, l...|        81|[despite, perfect...|        5|[bankruptcy, unpa...|        4| 0.1111111111111111|
# |      On XX/XX/XXXX, I ...|on xx xx xxxx  i ...|[on, xx, xx, xxxx...|[xx, xx, xxxx, si...|       244|           [greatly]|        1|[closing, incorre...|       17|-0.8888888888888888|
# |      Collector has con...|collector has con...|[collector, has, ...|[collector, conta...|        19|                  []|        0|                  []|        0|               null|
# |      Federal Student l...|federal student l...|[federal, student...|[federal, student...|       149|              [able]|        1|[error, incorrect...|       14|-0.8666666666666667|
# |      Capital One adver...|capital one adver...|[capital, one, ad...|[capital, one, ad...|        70|[rewards, rewards...|        6|[terminate, misle...|        4|                0.2|
# |      Commonwealth Fina...|commonwealth fina...|[commonwealth, fi...|[commonwealth, fi...|        48|                  []|        0|                  []|        0|               null|
# |      In XXXX of XXXX I...|in xxxx of xxxx i...|[in, xxxx, of, xx...|[xxxx, xxxx, noti...|        95|                  []|        0|[overcharged, ove...|        8|               -1.0|
# |      On XXXX XXXX, 201...|on xxxx xxxx  201...|[on, xxxx, xxxx, ...|[xxxx, xxxx, 2015...|        94|                  []|        0|[adverse, denial,...|        7|               -1.0|
# |      XXXX XXXX, 2015 I...|xxxx xxxx  2015 i...|[xxxx, xxxx, 2015...|[xxxx, xxxx, 2015...|       118|                  []|        0|[serious, launder...|        6|               -1.0|
# |      AFNI is continuin...|afni is continuin...|[afni, is, contin...|[afni, continuing...|        53|           [despite]|        1|[ignored, disputing]|        2|-0.3333333333333333|
# |      After sending bac...|after sending bac...|[after, sending, ...|[sending, back, r...|        27|                  []|        0|[refuse, incorrec...|        4|               -1.0|
# |      I opened a new CC...|i opened a new cc...|[i, opened, a, ne...|[opened, new, cc,...|       123|                  []|        0|[closing, late, u...|        4|               -1.0|
# |      Penn Credit is at...|penn credit is at...|[penn, credit, is...|[penn, credit, at...|        36|                  []|        0|           [alleged]|        1|               -1.0|
# |      I am XXXX militar...|i am xxxx militar...|[i, am, xxxx, mil...|[xxxx, military, ...|       121|                  []|        0|[missed, incompet...|        2|               -1.0|
# |      I disputed XXXX p...|i disputed xxxx p...|[i, disputed, xxx...|[disputed, xxxx, ...|        49|         [satisfied]|        1|[disputed, invest...|        4|               -0.6|
# |      The initial call ...|the initial call ...|[the, initial, ca...|[initial, call, r...|        73|                  []|        0|    [cease, refused]|        2|               -1.0|
# |      Hello, my name is...|hello  my name is...|[hello, my, name,...|[hello, name, xxx...|       236|                  []|        0|[unexpectedly, er...|        8|               -1.0|
# |      GreenTree Mortgag...|greentree mortgag...|[greentree, mortg...|[greentree, mortg...|        49|                  []|        0|              [late]|        1|               -1.0|
# |      I filed bankruptc...|i filed bankruptc...|[i, filed, bankru...|[filed, bankruptc...|       178|         [excellent]|        1|[bankruptcy, bank...|       15|             -0.875|
# |      Contacted by Conc...|contacted by conc...|[contacted, by, c...|[contacted, conco...|        65|[outstanding, res...|        2|                  []|        0|                1.0|
# |      There is a collec...|there is a collec...|[there, is, a, co...|[collection, repo...|        37|                  []|        0|                  []|        0|               null|
# |      We are working wi...|we are working wi...|[we, are, working...|[working, mortgag...|        53|                  []|        0|              [lose]|        1|               -1.0|
# |      US Bank notified ...|us bank notified ...|[us, bank, notifi...|[us, bank, notifi...|        56|[benefit, benefit...|        5| [losing, unwilling]|        2|0.42857142857142855|
# |      My issue with Nat...|my issue with nat...|[my, issue, with,...|[issue, nationsta...|       193|                  []|        0|[late, missed, la...|       19|               -1.0|
# |      The company has f...|the company has f...|[the, company, ha...|[company, failed,...|        17|                  []|        0|[failed, bankrupt...|        3|               -1.0|
# |      I seen some a irr...|i seen some a irr...|[i, seen, some, a...|[seen, irregular,...|       123|                  []|        0|[irregular, ignor...|        6|               -1.0|
# |      I was a XXXX, who...|i was a xxxx  who...|[i, was, a, xxxx,...|[xxxx, advertisin...|        87|                  []|        0|[dropped, complaint]|        2|               -1.0|
# |      transd union is r...|transd union is r...|[transd, union, i...|[transd, union, r...|        33|                  []|        0|[error, error, wr...|        6|               -1.0|
# |      CASE NUMBER XXXX ...|case number xxxx ...|[case, number, xx...|[case, number, xx...|        26|                  []|        0|           [failure]|        1|               -1.0|
# |      Capio Partners ha...|capio partners ha...|[capio, partners,...|[capio, partners,...|        38|                  []|        0|         [disputing]|        1|               -1.0|
# |      I was enrolling a...|i was enrolling a...|[i, was, enrollin...|[enrolling, xxxx,...|       121|        [encouraged]|        1|[problems, sued, ...|        3|               -0.5|
# |      Although I am beh...|although i am beh...|[although, i, am,...|[although, behind...|        58|                  []|        0|          [harassed]|        1|               -1.0|
# |      Borrowers submitt...|borrowers submitt...|[borrowers, submi...|[borrowers, submi...|        38|                  []|        0|        [incomplete]|        1|               -1.0|
# |      I filed a complai...|i filed a complai...|[i, filed, a, com...|[filed, complaint...|        90|            [better]|        1|[complaint, compl...|        5|-0.6666666666666666|
# |      There is a previo...|there is a previo...|[there, is, a, pr...|[previous, compla...|       163|                  []|        0|[complaint, compl...|        4|               -1.0|
# |      Dear Sir / Madam,...|dear sir   madam ...|[dear, sir, madam...|[dear, sir, madam...|       293|           [resolve]|        1|[mistake, mistake...|       14|-0.8666666666666667|
# |      In XXXX I signed ...|in xxxx i signed ...|[in, xxxx, i, sig...|[xxxx, signed, co...|       112|                  []|        0|[suffered, diffic...|        5|               -1.0|
# |      I am from XXXX an...|i am from xxxx an...|[i, am, from, xxx...|[xxxx, recently, ...|       118|           [resolve]|        1|[misleading, aler...|        3|               -0.5|
# |      I have never had ...|i have never had ...|[i, have, never, ...|[never, late, pay...|        50|                  []|        0|[late, late, erro...|        5|               -1.0|
# |      To whom it may co...|to whom it may co...|[to, whom, it, ma...|[may, concern, wr...|        43|         [attaining]|        1|[concern, dispute...|        7|              -0.75|
# +--------------------------+--------------------+--------------------+--------------------+----------+--------------------+---------+--------------------+---------+-------------------+
# only showing top 50 rows

# %%
df = df.drop('Consumercomplaintnarrative','Nr','Spl')

# %% [markdown]
# ### Company public response
#
# $ $
#
# This feature is largely unpopulated (73%) or gets the standard "no public response" from either the company (6%) or CFPB (14%). This field can be dropped.

# %%
df.createOrReplaceTempView("Resp")

RespDF = spark.sql("SELECT Companypublicresponse, count(*) as cnt \
                    FROM Resp \
                    GROUP BY Companypublicresponse \
                    ORDER BY cnt DESC")
RespDF.show()
# Out:
# +---------------------+------+
# |Companypublicresponse|   cnt|
# +---------------------+------+
# |                xxxxx|703992|
# | Company has respo...|196521|
# | Company chooses n...| 52473|
# | Company believes ...| 47846|
# | Company believes ...|  4548|
# | Company disputes ...|  4149|
# | Company believes ...|  3345|
# | Company believes ...|  3030|
# | Company can't ver...|  1919|
# | Company believes ...|  1843|
# | Company believes ...|    53|
# +---------------------+------+

# %%
df = df.drop('Companypublicresponse')

# %% [markdown]
# ### Companies
# $ $
#
# 50 companies account for 75% of the complaints even though there are 4300 companies in the dataset. Even among the top companies, the 15 most-complained about companies make up 60% of the complaints.
#
# $ $

# %%
# Companies in descending order of complaint frequency 
# Obtain percent frequencies
df.createOrReplaceTempView('TView1')

DF1 = spark.sql("SELECT Company, count(*) as Cnt \
                 FROM TView1 \
                 GROUP BY Company \
                 ORDER BY Cnt DESC")

DF1.createOrReplaceTempView('TView2')

DF2 = spark.sql("SELECT Company, Cnt, \
                 Cnt/(SELECT SUM(Cnt) from TView2 Temp1) Perc from TView2")\
           .collect()
C = spark.createDataFrame(DF2)

# %%
# https://stackoverflow.com/questions/46574860/how-can-i-obtain-percentage-frequencies-in-pyspark
# Suggested solution
df.createOrReplaceTempView('Comp')

CompDF = spark.sql("SELECT Company,cnt/(SELECT SUM(cnt) from (SELECT Company, count(*) as cnt\
    FROM Comp GROUP BY Company ORDER BY cnt DESC) temp_tab) sum_freq from\
    (SELECT Company, count(*) as cnt FROM Comp GROUP BY Company ORDER BY cnt DESC)").collect()
C = spark.createDataFrame(CompDF)
C.show()
# Out:
# +--------------------+--------------------+
# |             Company|            sum_freq|
# +--------------------+--------------------+
# |       EQUIFAX, INC.| 0.08164209944112054|
# |BANK OF AMERICA, ...| 0.07278573803175188|
# |Experian Informat...| 0.07079205153576623|
# |TRANSUNION INTERM...| 0.06445010831415321|
# |WELLS FARGO & COM...|0.060940317871884316|
# |JPMORGAN CHASE & CO.|0.050150090368032765|
# |      CITIBANK, N.A.|0.040793591175608185|
# |CAPITAL ONE FINAN...| 0.02630332473946254|
# |OCWEN LOAN SERVIC...|0.025761999138978482|
# |Navient Solutions...| 0.02377419661691113|
# | NATIONSTAR MORTGAGE|0.018155001524929906|
# | SYNCHRONY FINANCIAL| 0.01675363507005361|
# |        U.S. BANCORP|0.014442213982479487|
# |Ditech Financial LLC|0.012666234521471111|
# |AMERICAN EXPRESS ...| 0.01050975808041235|
# |       PNC Bank N.A.|0.009887037507391743|
# |ENCORE CAPITAL GR...|0.009397687009852714|
# |       DISCOVER BANK|0.008154207188450936|
# |HSBC NORTH AMERIC...|0.007659953379313321|
# |TD BANK US HOLDIN...|0.007637398145959818|
# +--------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ### State and ZIP
# $ $
# Complaints distrubution is also skewed heavily towards states with larger population. State and ZIP code features are dropped from the analysis.
# $ $

# %%
# States in descending order of complaint frequency 
# Obtain percent frequencies also

df.createOrReplaceTempView('TView1')

DF1 = spark.sql("SELECT State, count(*) as Cnt \
                 FROM TView1 \
                 GROUP BY State \
                 ORDER BY Cnt DESC")

DF1.createOrReplaceTempView('TView2')

DF2 = spark.sql("SELECT State, Cnt, \
                 Cnt/(SELECT SUM(Cnt) from TView2 Temp1) Perc from TView2")\
           .collect()
C = spark.createDataFrame(DF2)
C.show()
# Out:
# +-----+------+--------------------+
# |State|   Cnt|                Perc|
# +-----+------+--------------------+
# |   CA|142992| 0.14022686642104346|
# |   FL| 97460| 0.09557534967966666|
# |   TX| 82779| 0.08117824616389417|
# |   NY| 68499|  0.0671743882383284|
# |   GA| 51345| 0.05035210680589457|
# |   NJ| 39141| 0.03838410385606231|
# |   IL| 38848|0.038096769796385085|
# |   PA| 35327|0.034643857768659796|
# |   VA| 31058| 0.03045741032578583|
# |   OH| 30818| 0.03022205136905363|
# |   MD| 30630|0.030037686852946742|
# |   NC| 30492| 0.02990235545282573|
# |   MI| 24778|0.024298850957959986|
# |   AZ| 22279|0.021848175820985978|
# |   WA| 20482|0.020085925632453646|
# |   MA| 18774|0.018410954390376173|
# |   CO| 17041| 0.01671146659030576|
# |   TN| 16576|0.016255458611637127|
# |   SC| 14316|0.014039161769075598|
# |   MO| 13763|0.013496855506271825|
# +-----+------+--------------------+
# only showing top 20 rows

# %%
# Drop Zip code from the dataset
df = df.drop('ZIPcode')

# %% [markdown]
# ### Tags

# %%
# Tags 
# Obtain percent frequencies also
# Most of the tags are blank
df.createOrReplaceTempView('TView1')

DF1 = spark.sql("SELECT Tags, count(*) as Cnt \
                 FROM TView1 \
                 GROUP BY Tags \
                 ORDER BY Cnt DESC")

DF1.createOrReplaceTempView('TView2')

DF2 = spark.sql("SELECT Tags, Cnt, \
                 Cnt/(SELECT SUM(Cnt) from TView2 Temp1) Perc from TView2")\
           .collect()
C = spark.createDataFrame(DF2)
C.show()
# Out:
# +--------------------+------+--------------------+
# |                Tags|   Cnt|                Perc|
# +--------------------+------+--------------------+
# |               xxxxx|878753|  0.8617599554387042|
# |      Older American| 68592| 0.06726558983406213|
# |       Servicemember| 61220| 0.06003614721310479|
# |Older American, S...| 11154|0.010938307514128892|
# +--------------------+------+--------------------+

# %%
df = df.drop('Tags')

# %% [markdown]
# ### Consumer consent provided?

# %%
# Counts and percent frequencies also
df.createOrReplaceTempView('TView1')

DF1 = spark.sql("SELECT Consumerconsentprovided, count(*) as Cnt \
                 FROM TView1 \
                 GROUP BY Consumerconsentprovided \
                 ORDER BY Cnt DESC")
DF1.createOrReplaceTempView('TView2')

DF2 = spark.sql("SELECT Consumerconsentprovided, Cnt, \
                 Cnt/(SELECT SUM(Cnt) from TView2 Temp1) Perc from TView2")\
           .collect()
C = spark.createDataFrame(DF2)
C.show()
# Out:
# +-----------------------+------+-------------------+
# |Consumerconsentprovided|   Cnt|               Perc|
# +-----------------------+------+-------------------+
# |                  xxxxx|532240| 0.5219477130464373|
# |       Consent provided|275265| 0.2699420134370351|
# |   Consent not provided|198728| 0.1948850614728175|
# |                  Other| 12506|0.01226416297038694|
# |      Consent withdrawn|   980|9.61049073323141E-4|
# +-----------------------+------+-------------------+

# %%
# For the majority of cases, whether consent is provided is unknown
df = df.na.replace(['xxxxx','Consent withdrawn'], ['Other','Other'], 'Consumerconsentprovided')

# %% [markdown]
# ### Submitted via

# %%
# Counts and percent frequencies
df.createOrReplaceTempView('TView1')

DF1 = spark.sql("SELECT Submittedvia, count(*) as Cnt \
                 FROM TView1 \
                 GROUP BY Submittedvia \
                 ORDER BY Cnt DESC")
DF1.createOrReplaceTempView('TView2')

DF2 = spark.sql("SELECT Submittedvia, Cnt, \
                 Cnt/(SELECT SUM(Cnt) from TView2 Temp1) Perc from TView2")\
           .collect()
C = spark.createDataFrame(DF2)
C.show()
# Out:
# +------------+------+--------------------+
# |Submittedvia|   Cnt|                Perc|
# +------------+------+--------------------+
# |         Web|730749|  0.7166180094712367|
# |    Referral|151027|  0.1481064881599735|
# |       Phone| 63295| 0.06207102152651858|
# | Postal mail| 59203|0.058058151314234606|
# |         Fax| 15082|0.014790349105979195|
# |       Email|   363|3.559804220574491...|
# +------------+------+--------------------+

# %% [markdown]
# ### Company response to consumer

# %%
# Counts and percent frequencies
df.createOrReplaceTempView('TView1')

DF1 = spark.sql("SELECT Companyresponsetoconsumer, count(*) as Cnt \
                 FROM TView1 \
                 GROUP BY Companyresponsetoconsumer \
                 ORDER BY Cnt DESC")

DF1.createOrReplaceTempView('TView2')

DF2 = spark.sql("SELECT Companyresponsetoconsumer, Cnt, \
                 Cnt/(SELECT SUM(Cnt) from TView2 Temp1) Perc from TView2")\
           .collect()
C = spark.createDataFrame(DF2)
C.show()
# Out:
# +-------------------------+------+--------------------+
# |Companyresponsetoconsumer|   Cnt|                Perc|
# +-------------------------+------+--------------------+
# |     Closed with expla...|782205|  0.7670789697946199|
# |     Closed with non-m...|122951| 0.12057341287158521|
# |     Closed with monet...| 62121| 0.06091972396317025|
# |     Closed without re...| 17868|0.017522474328712127|
# |                   Closed| 17611| 0.01727044411254473|
# |              In progress|  6672|0.006542978997155099|
# |       Closed with relief|  5304|0.005201432943781571|
# |        Untimely response|  4984|0.004887621001471974|
# |                    xxxxx|     3|2.941986959152472...|
# +-------------------------+------+--------------------+

# %% [markdown]
# ### Timely response?

# %%
# Counts and percent frequencies
df.createOrReplaceTempView('TView1')

DF1 = spark.sql("SELECT Timelyresponse, count(*) as Cnt \
                 FROM TView1 \
                 GROUP BY Timelyresponse \
                 ORDER BY Cnt DESC")
#DF1.show()
DF1.createOrReplaceTempView('TView2')

DF2 = spark.sql("SELECT Timelyresponse, Cnt, \
                 Cnt/(SELECT SUM(Cnt) from TView2 Temp1) Perc from TView2")\
           .collect()
C = spark.createDataFrame(DF2)
C.show()
# Out:
# +--------------+------+-------------------+
# |Timelyresponse|   Cnt|               Perc|
# +--------------+------+-------------------+
# |           Yes|992040| 0.9728562476525395|
# |            No| 27679|0.02714375234746043|
# +--------------+------+-------------------+

# %% [markdown]
# ### Consumer disputed?

# %%
# Counts and percent frequencies
df.createOrReplaceTempView('TView1')

DF1 = spark.sql("SELECT Consumerdisputed, count(*) as Cnt \
                 FROM TView1 \
                 GROUP BY Consumerdisputed \
                 ORDER BY Cnt DESC")
#DF1.show()
DF1.createOrReplaceTempView('TView2')

DF2 = spark.sql("SELECT Consumerdisputed, Cnt, \
                 Cnt/(SELECT SUM(Cnt) from TView2 Temp1) Perc from TView2")\
           .collect()
C = spark.createDataFrame(DF2)
C.show()
# Out:
# +----------------+------+-------------------+
# |Consumerdisputed|   Cnt|               Perc|
# +----------------+------+-------------------+
# |              No|620184| 0.6081910800916723|
# |           xxxxx|251157|0.24630020623328583|
# |             Yes|148378|0.14550871367504184|
# +----------------+------+-------------------+

# %%
# For about 7.5% of observations, the answer is blank. recode as Other
df = df.na.replace(['xxxxx'], ['Other'], 'Consumerdisputed')
#df.show()

# %% [markdown]
# $ $
# #### Dates: Date received and Date sent to company
# $ $

# %%
from pyspark.sql.functions import col, udf

# %%
# https://stackoverflow.com/questions/38080748/convert-pyspark-string-to-date-format
func =  udf (lambda x: datetime.strptime(x, '%m/%d/%Y'), DateType())

# %%
df = df.withColumn('DateRec', func(col('Datereceived')))
df = df.withColumn('DateSent', func(col('Datesenttocompany')))

# %%
# The original, string-typed dates are no longer necessary
df = df.drop('Datereceived','Datesenttocompany')

# %%
df = df.withColumn('DateDiff', datediff(df.DateSent, df.DateRec))

# %%
df = df.withColumn('Yr', year(df.DateRec))
df = df.withColumn('Mon', month(df.DateRec))

# %%
# Not surprisingly, how a complaint was submitted  
# has an effect on how long it takes CFPB to submit it
# group by column 'A' and 'B' then performing some function here
group_df = df.groupby(['Submittedvia'])
df_grouped = group_df.agg(avg("DateDiff").alias("avgC"), 
                          count("DateDiff").alias("countC"))
df_grouped.show() # print out the spark dataframe
# Out:
# +------------+-----------------+------+
# |Submittedvia|             avgC|countC|
# +------------+-----------------+------+
# |       Phone|4.503625878821392| 63295|
# |         Fax|5.519957565309641| 15082|
# |       Email|7.900826446280992|   363|
# |    Referral|5.894674462182259|151027|
# | Postal mail|7.814891137273449| 59203|
# |         Web|2.709548695927056|730749|
# +------------+-----------------+------+

# %%
df.groupby(['DateDiff']) \
  .agg(avg("DateDiff").alias("avgC"), count("DateDiff").alias("countC")) \
  .orderBy("DateDiff") \
  .show()
# Out:
# +--------+----+------+
# |DateDiff|avgC|countC|
# +--------+----+------+
# |      -1|-1.0|  7052|
# |       0| 0.0|578081|
# |       1| 1.0|100349|
# |       2| 2.0| 62993|
# |       3| 3.0| 50051|
# |       4| 4.0| 46486|
# |       5| 5.0| 41398|
# |       6| 6.0| 30536|
# |       7| 7.0| 19561|
# |       8| 8.0|  8757|
# |       9| 9.0|  5187|
# |      10|10.0|  4415|
# |      11|11.0|  3761|
# |      12|12.0|  3669|
# |      13|13.0|  3617|
# |      14|14.0|  3533|
# |      15|15.0|  3077|
# |      16|16.0|  2238|
# |      17|17.0|  2189|
# |      18|18.0|  1971|
# +--------+----+------+
# only showing top 20 rows

# %%
# Fold the extreme values (<0 and >8 days) 
df = df.withColumn('DtDiff', when(df.DateDiff > 8, 8).otherwise(when(df.DateDiff < 0, 0).otherwise(df.DateDiff)))

# %%
df = df.drop('DateDiff')
df.groupby(['DtDiff']) \
  .agg(count("DtDiff").alias("countC")) \
  .orderBy("DtDiff") \
  .show()
# Out:
# +------+------+
# |DtDiff|countC|
# +------+------+
# |     0|585133|
# |     1|100349|
# |     2| 62993|
# |     3| 50051|
# |     4| 46486|
# |     5| 41398|
# |     6| 30536|
# |     7| 19561|
# |     8| 83212|
# +------+------+

# %%
df.groupby(['Yr']) \
  .agg(count("Yr").alias("countC")) \
  .orderBy("Yr") \
  .show()
# Out:
# +----+------+
# |  Yr|countC|
# +----+------+
# |2011|  2536|
# |2012| 72373|
# |2013|108218|
# |2014|153053|
# |2015|168515|
# |2016|191491|
# |2017|243000|
# |2018| 80533|
# +----+------+

# %%
df.groupby(['Mon']) \
  .agg(count("Mon").alias("countC")) \
  .orderBy("Mon") \
  .show()
# Out:
# +---+------+
# |Mon|countC|
# +---+------+
# |  1| 96692|
# |  2| 91758|
# |  3|103344|
# |  4| 87603|
# |  5| 76469|
# |  6| 77550|
# |  7| 81845|
# |  8| 84503|
# |  9| 86875|
# | 10| 82065|
# | 11| 73819|
# | 12| 77196|
# +---+------+

# %%
# CSV doesn't support arrays
df = df.withColumn('Narrative', concat_ws(" ", 'Narr'))
df = df.withColumn('PosWords', concat_ws(" ", 'Pos'))
df = df.withColumn('NegWords', concat_ws(" ", 'Neg'))

# %%
df = df.drop('Narr','Pos','Neg')

# %%
df.printSchema()
# Out:
# root
#  |-- Company: string (nullable = true)
#  |-- State: string (nullable = true)
#  |-- Consumerconsentprovided: string (nullable = true)
#  |-- Submittedvia: string (nullable = true)
#  |-- Companyresponsetoconsumer: string (nullable = true)
#  |-- Timelyresponse: string (nullable = true)
#  |-- Consumerdisputed: string (nullable = true)
#  |-- Prod: string (nullable = true)
#  |-- Iss: string (nullable = true)
#  |-- NarrLength: integer (nullable = false)
#  |-- PosLength: integer (nullable = false)
#  |-- NegLength: integer (nullable = false)
#  |-- PSent: double (nullable = true)
#  |-- DateRec: date (nullable = true)
#  |-- DateSent: date (nullable = true)
#  |-- Yr: integer (nullable = true)
#  |-- Mon: integer (nullable = true)
#  |-- DtDiff: integer (nullable = true)
#  |-- Narrative: string (nullable = false)
#  |-- PosWords: string (nullable = false)
#  |-- NegWords: string (nullable = false)

# %%
# A final look at the transformed data frame
df.show()
# Out:
# +--------------------+-----+-----------------------+------------+-------------------------+--------------+----------------+--------------------+--------------------+----------+---------+---------+-----+----------+----------+----+---+------+---------+--------+--------+
# |             Company|State|Consumerconsentprovided|Submittedvia|Companyresponsetoconsumer|Timelyresponse|Consumerdisputed|                Prod|                 Iss|NarrLength|PosLength|NegLength|PSent|   DateRec|  DateSent|  Yr|Mon|DtDiff|Narrative|PosWords|NegWords|
# +--------------------+-----+-----------------------+------------+-------------------------+--------------+----------------+--------------------+--------------------+----------+---------+---------+-----+----------+----------+----+---+------+---------+--------+--------+
# |BANK OF AMERICA, ...|   OR|                  Other|         Web|     Closed with non-m...|           Yes|              No|Mortgage - conven...|Loan servicing, p...|         1|        0|        0| null|2012-05-21|2012-05-29|2012|  5|     8|    xxxxx|        |        |
# |JPMORGAN CHASE & CO.|   CA|                  Other|         Web|     Closed without re...|           Yes|              No|Credit card or pr...|APR or interest rate|         1|        0|        0| null|2011-12-07|2011-12-07|2011| 12|     0|    xxxxx|        |        |
# |WELLS FARGO & COM...|   CO|                  Other|    Referral|       Closed with relief|           Yes|              No|Credit card or pr...|               Other|         1|        0|        0| null|2011-12-01|2011-12-01|2011| 12|     0|    xxxxx|        |        |
# |WELLS FARGO & COM...|   CA|                  Other|    Referral|     Closed without re...|           Yes|              No|Credit card or pr...|               Other|         1|        0|        0| null|2011-12-02|2011-12-02|2011| 12|     0|    xxxxx|        |        |
# |JPMORGAN CHASE & CO.|   CA|                  Other|         Web|     Closed without re...|           Yes|              No|Credit card or pr...|Advertising and m...|         1|        0|        0| null|2011-12-12|2011-12-16|2011| 12|     4|    xxxxx|        |        |
# |JPMORGAN CHASE & CO.|   IL|                  Other|         Web|     Closed without re...|           Yes|              No|Mortgage - conven...|Loan modification...|         1|        0|        0| null|2011-12-13|2011-12-16|2011| 12|     3|    xxxxx|        |        |
# |WELLS FARGO & COM...|   CA|                  Other|         Web|     Closed without re...|           Yes|             Yes|Mortgage - FHA mo...|Loan servicing, p...|         1|        0|        0| null|2011-12-20|2011-12-22|2011| 12|     2|    xxxxx|        |        |
# |BANK OF AMERICA, ...|   AR|                  Other|         Web|        Untimely response|            No|              No|Credit card or pr...|               Other|         1|        0|        0| null|2011-12-22|2011-12-23|2011| 12|     1|    xxxxx|        |        |
# |SUNTRUST BANKS, INC.|   GA|                  Other|         Web|       Closed with relief|           Yes|              No|Credit card or pr...|Advertising and m...|         1|        0|        0| null|2011-12-27|2012-01-06|2011| 12|     8|    xxxxx|        |        |
# |BANK OF AMERICA, ...|   CA|                  Other|         Web|     Closed without re...|           Yes|              No|    Mortgage - other|Loan modification...|         1|        0|        0| null|2011-12-28|2011-12-29|2011| 12|     1|    xxxxx|        |        |
# |OCWEN LOAN SERVIC...|   CA|                  Other|    Referral|     Closed without re...|           Yes|              No|    Mortgage - other|Loan modification...|         1|        0|        0| null|2011-12-29|2011-12-29|2011| 12|     0|    xxxxx|        |        |
# |      CITIBANK, N.A.|   NY|                  Other|         Web|     Closed without re...|           Yes|              No|Credit card or pr...|APR or interest rate|         1|        0|        0| null|2012-01-04|2012-01-04|2012|  1|     0|    xxxxx|        |        |
# |BANK OF AMERICA, ...|   DC|                  Other|         Web|       Closed with relief|           Yes|              No|Credit card or pr...|APR or interest rate|         1|        0|        0| null|2012-01-04|2012-01-05|2012|  1|     1|    xxxxx|        |        |
# |Ditech Financial LLC|   GA|                  Other|    Referral|     Closed without re...|           Yes|              No|Mortgage - conven...|Credit decision /...|         1|        0|        0| null|2012-01-05|2012-03-23|2012|  1|     8|    xxxxx|        |        |
# |BANK OF AMERICA, ...|   VA|                  Other|         Web|     Closed without re...|           Yes|              No|Mortgage - conven...|Loan modification...|         1|        0|        0| null|2012-01-05|2012-01-06|2012|  1|     1|    xxxxx|        |        |
# |      CITIBANK, N.A.|   OH|                  Other|         Web|     Closed without re...|           Yes|              No|Mortgage - FHA mo...|Loan modification...|         1|        0|        0| null|2012-01-05|2012-01-10|2012|  1|     5|    xxxxx|        |        |
# | QUICKEN LOANS, INC.|   OR|                  Other|         Web|     Closed without re...|           Yes|              No|Mortgage - conven...|Application, orig...|         1|        0|        0| null|2012-01-06|2012-03-09|2012|  1|     8|    xxxxx|        |        |
# |OCWEN LOAN SERVIC...|   VA|                  Other|         Web|     Closed without re...|           Yes|              No|Mortgage - conven...|Loan servicing, p...|         1|        0|        0| null|2012-01-09|2012-03-23|2012|  1|     8|    xxxxx|        |        |
# |JPMORGAN CHASE & CO.|   TX|                  Other|         Web|     Closed without re...|           Yes|             Yes|Mortgage - FHA mo...|Loan modification...|         1|        0|        0| null|2012-01-25|2012-01-26|2012|  1|     1|    xxxxx|        |        |
# |BANK OF AMERICA, ...|   TX|                  Other|         Web|     Closed without re...|           Yes|             Yes|Mortgage - conven...|Loan modification...|         1|        0|        0| null|2012-01-26|2012-02-02|2012|  1|     7|    xxxxx|        |        |
# +--------------------+-----+-----------------------+------------+-------------------------+--------------+----------------+--------------------+--------------------+----------+---------+---------+-----+----------+----------+----+---+------+---------+--------+--------+
# only showing top 20 rows

# %%
df.write.option("header", "true").csv("compFinal")

# %%
# This will consolidate all output files into a single CSV file
# The merge will result in duplicate header rows
# The resulting CSV file will have to be filtered
# !hadoop fs -getmerge -nl compFinal ComplaintsFinal.csv

# %%
print time.clock() - beg_time, "seconds"
# Out:
# 173.13 seconds
